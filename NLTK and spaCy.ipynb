# %%
# import from nltk
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
# Word tokenise
tokens = word_tokenize(text)
# print(tokens)
# tag some text
tagged = nltk.pos_tag(tokens)
print(tagged[:5])
POS = {
    "CD": "cardinal numbers",
    "AT": "articles",
    "JJ": "adjectives",
    "NN": "nouns formed from oadjectives & nouns (default)",
    "RB": "adverbs",
    "NNS": "plural nouns",
    "VBG": "gerunds",
    "VBD": "past tense verbs"
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9e9d94ebae17> in <module>
#       1 # Word tokenise
# ----> 2 tokens = word_tokenize(text)
#       3 # print(tokens)
#       4 # tag some text
#       5 tagged = nltk.pos_tag(tokens)
#
# NameError: name 'text' is not defined

# %%
# Stemming
stemmer = PorterStemmer()
stemmed = [stemmer.stem(w) for w in tokens]
print(" ".join(stemmed))

# %%
# lemmatizing
wnl = WordNetLemmatizer()
lemmatized = [wnl.lemmatize(w) for w in tokens]
print(" ".join(lemmatized))

# %%
# Stopword removal
sw = stopwords.words("English")
content = [w for w in tokens if w.lower() not in sw]
" ".join(content)

# %%
synsets = wordnet.synsets('phone')

for synset in synsets:
    print(synset.lemma_names())

# %%
synsets = wordnet.synsets('cell')

for synset in synsets:
    print(synset.lemma_names())

# %%
synsets = wordnet.synsets('mobile phone')

for synset in synsets:
    print(synset.lemma_names())

# %%
phone = wordnet.synsets('car')
synsets = phone[0].hyponyms()
for synset in synsets:
    print(synset.lemma_names())
    print(synset.definition())
    print(synset.examples())

# %%
nltk.help.upenn_tagset()

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets('good'):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.extend([n.name() for n in l.antonyms()])
            
print(set(synonyms), set(antonyms))

# %%
# similarities

w1 = wordnet.synset("agriculture.n.01")
w2 = wordnet.synset("farm.n.01")
print(w1.wup_similarity(w2))

# %% [markdown]
# ## Spacy

# %% [markdown]
# https://spacy.io/

# %%
# # !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_md
# !python -m spacy download en_core_web_lg

# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.6.2-py3-none-any.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 10.3 MB/s eta 0:00:01
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.6.2

# %%
from spacy.lang.en import English
import spacy

nlp = English()
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("its official Apple is the first U.S. public company to reach 1 trillion market value")
# for token in doc:
#     print(token.text, token.pos_, token.dep_) # token's text, part-of-speech tag, dependency label
    
# entity text, label
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Apple ORG
# first ORDINAL
# U.S. GPE
# 1 trillion CARDINAL

# %% [markdown]
# ## Pipeline
# ## Doc
# ## Token
# ## Span
# ## lexical attributes: like_num, is_alpha, is_punc

# %%
# nlp = spacy.load("en_core_web_lg")

doc1 = nlp("irrigation")
doc2 = nlp("water")

# doc1 = nlp("tired")
# doc2 = nlp("exhausted")

print(doc1.similarity(doc2))
# Out:
# 0.8554847737928696
# /var/folders/n1/w0jj77mn7yv1tywxf17vqh300000gn/T/ipykernel_12573/3108467103.py:9: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(doc1.similarity(doc2))

# %%
doc1 = nlp('ccp')
doc2 = nlp('vueJS')
print(doc1, doc2)
print(doc1.similarity(doc2))
# Out:
# ccp vueJS
# 0.0
# /var/folders/n1/w0jj77mn7yv1tywxf17vqh300000gn/T/ipykernel_12573/3208646692.py:4: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   print(doc1.similarity(doc2))

# %%
with open('output.txt') as f:
    transcript = f.read()
    
subtitle = Subtitle(transcript)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/n1/w0jj77mn7yv1tywxf17vqh300000gn/T/ipykernel_4554/3954160997.py in <module>
# ----> 1 with open('output.txt') as f:
#       2     transcript = f.read()
#       3
#       4 subtitle = Subtitle(transcript)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output.txt'

# %%
subtitle.text

# %%
from spacy import displacy

nlp = spacy.load('en_core_web_lg')
doc = nlp(text)
html = displacy.render(doc, style="ent", jupyter=False)

html
# with open('data_vis.html', 'w') as f:
#     f.write(html)
# Out:
# '<div class="entities" style="line-height: 2.5; direction: ltr">[Music] hello and welcome back to this new video on my series on Spacey for the purposes of performing D H in this video we\'re gonna be looking at something kind of new so in the last video I showed you how to break down words to their core roots or ulemas through limitation in this video we\'re gonna be looking at how to start to visualize our data our text data using \n<mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    Spacey\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>\n</mark>\n what we\'re gonna produce is something that looks kind of similar to what you were probably used to in \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    7th\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>\n</mark>\n or \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    8th\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>\n</mark>\n grade \n<mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    English\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>\n</mark>\n maybe \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    6th\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>\n</mark>\n grade or you created these sentence trees or the ways in which words in the sentence relate to one another so we\'re gonna do that in Spacey so the \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    first\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>\n</mark>\n thing we\'re gonna do is we\'re gonna have to import the ability thing that allows us to actually visualize data and that\'s called display C so what we\'re gonna do is fret say from Spacey import display C just like that and now once we\'ve got that imported now we can start kind of working with our data and the last few videos we\'ve really looked at sentence to hear all of this information and this video I want to look at this sentence here and I\'ve already figured out that I need to type in \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    number eight\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>\n</mark>\n to get to that and the reason why I\'m picking this one is because it\'s a simpler sentence unlike this one which means we can kind of look at more of it on one screen so what I\'m going to do is I\'m going to simply type in HTML I\'m gonna create an object here and I\'m gonna stay display C render and I\'m gonna identify \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    two\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>\n</mark>\n ...

# %%
with open('data_vis.html', 'w') as f:
    f.write(html)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/n1/w0jj77mn7yv1tywxf17vqh300000gn/T/ipykernel_6420/3960638376.py in <module>
#       1 with open('data_vis.html', 'w') as f:
# ----> 2     f.write(html)
#
# TypeError: write() argument must be str, not None

# %%
html

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a149fb9b912f41699a037ec67824a948-0" class="displacy" width="72325" height="2762.0" direction="ltr" style="max-width: none; height: 2762.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">angular</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">typescript-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">framework</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">building</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">user</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">interfaces</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">developed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">released</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">2016</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">sequel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">angularjs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">angular</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">developer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">hit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2672.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">ground</tspan>
#     <tspan class="displa

# %%
# pyspellchecker
# https://github.com/barrust/pyspellchecker
from spellchecker import SpellChecker
from caption import pipeline

spell = SpellChecker()

# %%
tokens = word_tokenize(text)

# %%
tokens_first100 = tokens[:100]

# %%
spell.

# %%
# find words that may be misspelled
misspelled = spell.unknown(tokens)

# %%
misspelled
# Out:
# {"'ll",
#  "'s",
#  'angularjs',
#  'component-based',
#  'fireship',
#  'html',
#  'iterable',
#  'ng',
#  'ng4',
#  'ngf',
#  'pre-configured',
#  're-render',
#  're-renders',
#  'server-side',
#  'typescript-based'}

# %%
spell.correction('tpescrupt')
# Out:
# 'typescript'

# %% [markdown]
# ## Training spell checker with text

# %%
# Word tokenize, lemmatize and stop word removal
# import from nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

def process_text(text):
    # Word tokenize
    tokens = word_tokenize(text)
    # Lemmatize
    wnl = WordNetLemmatizer()
    lemmatized = [wnl.lemmatize(w) for w in tokens]
    # Stop word removal
    sw = stopwords.words("English")
    content = [w for w in tokens if w.lower() not in sw]
    return content

# %%
# Spell check
# pyspellchecker
# https://github.com/barrust/pyspellchecker

from spellchecker import SpellChecker
from caption import pipeline

# %%
url = 'https://www.youtube.com/watch?v=Ata9cSC2WpM'
text = pipeline(url)['caption_fulltext']

def spellchecker_load(text):
    # load spell checked
    spell = SpellChecker()
    # process text
    tokens = process_text(text)
    # add text to word frequency list
    spell.word_frequency.load_words(tokens)
    # return model
    return spell

spell = spellchecker_load(text)
# Out:
# YoutubeCaption created

# %% [markdown]
# e.g. tokens: ['angular',
#  'typescript-based',
#  'framework',
#  'building',
#  'user',
#  'interfaces',
#  'developed',
#  'google',
#  'released',
#  '2016',
#  'sequel',
#  'angularjs',
#  'angular',
#  'developer', ...]

# %%
spell.correction('typrscript-baed')
# Out:
# 'typescript-based'

# %% [markdown]
# ## word search:
# 1. strip to remove leading and trailing space
# 1. regex to remove punctuation from either side
# 1. if search contains a single word (only alphanumerics)
#     1. lemmatize word and match exact lemmatized token
#     1. find synonyms and match synonym token
#     1. find token with similarity > 0.7
# 1. if search contains multiple words
#     1. replace all punctuation with space
#     1. replace multiples of space to single space
#     1. search text for exact match with \[0 to 5\] characters between each word
#     1. * alternatives: chunking, entity recognition
#        * limitations: punctuation, missing mispelled/ similar words

# %%
caption = pipeline('https://www.youtube.com/watch?v=4duqI8WyfqE')
text = caption['caption_fulltext']

text
# Out:
# YoutubeCaption created
# "in the not so distant future you'll likely be writing far fewer lines of code than you are today because artificial intelligence is coming to a vs code near you microsoft aka github just announced copilot yesterday a tool powered by gpt3 capable of writing code automatically all you have to do is write a descriptive function name or some comments and it will automatically fill in the implementation details for you and it's not just inserting a snippet this is actual novel code that has never been seen before it looks at the code you've already written in your project as context and attempts to generate new code to match it perfectly for example imagine you've written a react component and you now want to write a unit test for it just write a comment describing what you want to test and copilot will generate the code based on your component and the testing framework that you're using or say you want to calculate the number of days between two dates for me that's an instant google search then stack overflow copy and paste with copilot all i have to do is write a function name and it implements the function body for me automatically if i'm not perfectly happy with the implementation i can click a button to get the next prediction anything that might have brought you to stack overflow can be autocompleted in your ide and custom tailored to fit your code base developers like to joke about how often they google things and copy answers from stack overflow so you can only imagine how big of a time saver this is going to be i just got access to copilot myself so let's dive in and see how useful it really is i just installed the extension and bs code which required me to authenticate with my github account i've got a front-end vanilla javascript project here with files for my html css and javascript you'll notice a little copilot icon down here at the bottom that just allows you to toggle it on or off the first thing i want to try is to define a function called intersection of arrays and see if it can complete the body of that function successfully we'll give the function a name of intersection of o and it just predicts the name of the function that we're going to write and it looks like it's being implemented correctly but there are multiple ways we could implement this function let's go ahead and delete the code back to the function name if we hover over the automatically generated code we can click next to cycle through different suggestions i actually don't see any i like here so i'm going to click the open copilot option that will synthesize 10 different possible solutions and it happens very fast like within one or two seconds but looking closer at the solutions it looks like they are all pretty much the same even though i know there are multiple different approaches to implementing an intersection of arrays the top answer on stack overflow actually has a cleaner implementation and i would have expected this to at least be an option in the results but let's move on and see if we can build a little counter app that has multiple moving parts first i'm going to define some state which is just a variable equal to zero you'll notice that it's trying to make predictions as i'm writing out this variable that is one thing that's kind of annoying it's almost a little too aggressive when making predictions it would be nice if the ai could predict when i actually want predictions also it predicts things for react and view even though i'm not in a reactor view project in any case the next thing i want to do here is grab a button from the dom i'll give the ai a hint by writing a comment and you'll notice that it actually auto-completes the comment for me it knows exactly what i want to do because it's such a common thing to do now that we have a button let's set up an event listener on the click event to increment the state each time that it's clicked now i start writing another comment i don't even type anything and it fills out that entire  ...

# %%
# import json
# sections = json.loads(caption['caption_sections'])
# sections[0]['cid'] = 0
# # calculate cumulative index: previous section's cid + number of characters in the previous section's subtitle
# for index, section in enumerate(sections[1:]):
#     section['cid'] = sections[index]['cid'] + len(sections[index+1]['subtitle'])
# print(sections)

# def find_section(startid, sections):
#     for section in sections:
#         if startid < section['cid']:
#             return section['section'] 
#     return -1
# Out:
# [{'section': '1', 'time_original': '00:00:00,320 --> 00:00:04,160', 'time': '0.32:4.16', 'subtitle': 'angular a typescript-based framework for', 'cid': 0}, {'section': '2', 'time_original': '00:00:02,720 --> 00:00:05,839', 'time': '2.7199999999999998:5.839', 'subtitle': 'building user interfaces', 'cid': 24}, {'section': '3', 'time_original': '00:00:04,160 --> 00:00:08,880', 'time': '4.16:8.88', 'subtitle': 'it was developed at google and released', 'cid': 63}, {'section': '4', 'time_original': '00:00:05,839 --> 00:00:10,400', 'time': '5.839:10.4', 'subtitle': 'in 2016 as the sequel to angularjs', 'cid': 97}, {'section': '5', 'time_original': '00:00:08,880 --> 00:00:11,759', 'time': '8.88:11.759', 'subtitle': 'as an angular developer you hit the', 'cid': 132}, {'section': '6', 'time_original': '00:00:10,400 --> 00:00:13,280', 'time': '10.4:13.28', 'subtitle': 'ground running with its extremely', 'cid': 165}, {'section': '7', 'time_original': '00:00:11,759 --> 00:00:14,400', 'time': '11.759:14.4', 'subtitle': 'powerful cli tool', 'cid': 182}, {'section': '8', 'time_original': '00:00:13,280 --> 00:00:16,160', 'time': '13.28:16.16', 'subtitle': 'when you generate your initial', 'cid': 212}, {'section': '9', 'time_original': '00:00:14,400 --> 00:00:16,640', 'time': '14.4:16.64', 'subtitle': 'application it comes pre-configured with', 'cid': 252}, {'section': '10', 'time_original': '00:00:16,160 --> 00:00:18,240', 'time': '16.16:18.24', 'subtitle': 'routing', 'cid': 259}, {'section': '11', 'time_original': '00:00:16,640 --> 00:00:20,160', 'time': '16.64:20.16', 'subtitle': 'a testing framework and your favorite', 'cid': 296}, {'section': '12', 'time_original': '00:00:18,240 --> 00:00:22,400', 'time': '18.24:22.4', 'subtitle': 'style preprocessor in addition', 'cid': 326}, {'section': '13', 'time_original': '00:00:20,160 --> 00:00:23,920', 'time': '20.16:23.92', 'subtitle': 'the magic ng add command can turn your', 'cid': 364}, {'section': '14', 'time_original': '00:00:22,400 --> 00:00:25,760', 'time': '22.4:25.76', 'subtitle': 'app into a progressive web app', 'cid': 394}, {'section': '15', 'time_original': '00:00:23,920 --> 00:00:27,359', 'time': '23.92:27.359', 'subtitle': 'add server-side rendering firebase', 'cid': 428}, {'section': '16', 'time_original': '00:00:25,760 --> 00:00:28,240', 'time': '25.76:28.24', 'subtitle': 'support and do a whole bunch of other', 'cid': 465}, {'section': '17', 'time_original': '00:00:27,359 --> 00:00:30,240', 'time': '27.359:30.24', 'subtitle': 'cool stuff', 'cid': 475}, {'section': '18', 'time_original': '00:00:28,240 --> 00:00:32,320', 'time': '28.24:32.32', 'subtitle': 'but at its core angular is just a', 'cid': 508}, {'section': '19', 'time_original': '00:00:30,240 --> 00:00:33,760', 'time': '30.24:33.76', 'subtitle': 'component-based ui library i can create', 'cid': 547}, {'section': '20', 'time_original': '00:00:32,320 --> 00:00:35,360', 'time': '32.32:35.36', 'subtitle': 'a component with the cli', 'cid': 571}, {'section': '21', 'time_original': '00:00:33,760 --> 00:00:36,880', 'time': '33.76:36.88', 'subtitle': 'and if we go into its typescript file', 'cid': 608}, {'section': '22', 'time_original': '00:00:35,360 --> 00:00:38,640', 'time': '35.36:38.64', 'subtitle': "you'll notice the component decorator", 'cid': 645}, {'section': '23', 'time_original': '00:00:36,880 --> 00:00:40,480', 'time': '36.88:40.48', 'subtitle': 'which makes this typescript class a', 'cid': 680}, {'section': '24', 'time_original': '00:00:38,640 --> 00:00:41,920', 'time': '38.64:41.92', 'subtitle': 'component any properties on this class', 'cid': 718}, {'section': '25', 'time_original': '00:00:40,480 --> 00:00:43,280', 'time': '40.48:43.28', 'subtitle': 'are considered reactive state', 'cid': 747}, {'section': '26', 'time_original': '00:00:41,920 --> 00:00:44,960', 'time': '41.92:44.96', 'subtitle': 'and when their values change the', 'cid': 779}, {'section': '27', 'time_original': '00:00:43,280 --> 00:00:47,039',  ...

# %%
for r in results:
    print(find_section(r['start'], sections))
# Out:
# 4
# 9
# 34
# -1
# -1

# %%
import re

def process_search_term(search):
#    remove leading and trailing space and punctuation
#     search = search.strip()
    search = re.sub(r'^\W*(.*?)\W*$', r'\1', search)
#     return alphanumeric tokens
    tokens = re.findall(r'(\w+)', search)
    return tokens

# %%
query = 'this-video'
search_tokens = process_search_term(query)

# %%
res = {}

if len(search_tokens) == 0:
    res = {'status': 400, 'message': "No search term parsed"}
elif len(search_tokens) == 1:
    pass
else:
    search = r'.{0,3}'.join(search_tokens)
    results = re.finditer(search, text)
    results = [{'start': m.start(), 'end': m.end(), 'match': m.group(0)} for m in results]
    res = {'status': 400, 'results': results}
    
print(results)
# Out:
# [{'start': 110, 'end': 120, 'match': 'this video'}, {'start': 279, 'end': 289, 'match': 'this video'}, {'start': 1062, 'end': 1072, 'match': 'this video'}, {'start': 8051, 'end': 8061, 'match': 'this video'}, {'start': 8190, 'end': 8200, 'match': 'this video'}]

# %%
search_tokens
# Out:
# ['this', 'video']

# %%
re.compile(('.').join(search_tokens))
# Out:
# re.compile(r'this.video', re.UNICODE)

# %%
re.findall(r'\d{1,3}', '00  33')
# Out:
# ['00', '33']

# %%
for match in results:
    print(match.start())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n1/w0jj77mn7yv1tywxf17vqh300000gn/T/ipykernel_30239/1874473410.py in <module>
#       1 for match in results:
# ----> 2     print(match.start())
#
# AttributeError: 'dict' object has no attribute 'start'
